# %% [markdown]
# > # **Introduction**
#
# Perkenalkan nama saya **Verindra Hernanda Putra**, nah notebook ini merupakan notebook dengan dataset yang saya ambil dari Kaggle yaitu "**Housing Price Prediction**", dengan harapan dataset ini bisa saya gunakan dengan baik dari **Week 1** sampai **Week 5** dalam kegiatan **Rekruitasi MBC Laboratory**

# %% [markdown]
# ![Screenshot (503).png](attachment:2299d65f-64f3-4491-92a2-b685eed298a1.png)

# %% [markdown]
# **TASK :** Regression Data - Prediksi Harga Rumah

# %%
# CaAs_Verindra Hernanda Putra - 1303223055

# Import Library

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# > # **EDA - Exploratory Data Analysis**

# %%
# Panggil Dataset
df = pd.read_csv("/kaggle/input/housing-price-prediction/Housing.csv")

# %%
# Tampilkan tabel
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# **Analisis Dataset**
#
# Jadi dataset ini merupakan dataset yang Berisi detail mobil dan berbagai fiturnya.
#
# Data-data kolom yang ada dalam dataset ini adalah :
# * **price :** Harga rumah **- Target**
# * **area :** Total luas rumah dalam kaki persegi.
# * **bedrooms :** Jumlah kamar tidur
# * **bathrooms :** Jumlah kamar mandi
# * **stories :** Jumlah lantai
# * **mainroad :** Apakah rumah terhubung dengan jalan utama (Ya/Tidak)
# * **guestroom :** Apakah rumah tersebut memiliki kamar tamu (Ya/Tidak)
# * **basement :** Apakah rumah tersebut memiliki ruang bawah tanah (Ya/Tidak)
# * **hotwaterheating :** Apakah rumah mempunyai sistem pemanas air panas (Ya/Tidak)
# * **airconditioning :** Apakah rumah mempunyai sistem AC (Ya/Tidak)
# * **parking :** Jumlah tempat parkir
# * **prefarea :** Apakah rumah terletak di area pilihan (Ya/Tidak)
# * **furnishingstatus :** Status perabotan rumah (Fully Furnished, Semi-Furnished, Unfurnished)
#
# **Total Kolom = 13 | Total Baris = 545**

# %%
# Statistik Deskriptif
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
# Visualisasi Data ( Kamar )
hitung_kamar = df['bedrooms'].value_counts()

plt.figure(figsize=(20, 10))
sns.barplot(x=hitung_kamar.index, y=hitung_kamar.values)
plt.title('Jumlah Tahun')
plt.xlabel('bedrooms')
plt.ylabel('Count')
plt.xticks()
plt.grid(axis='y')
plt.show()

# %%
print(hitung_kamar)
# Out:
# bedrooms
# 3    300
# 2    136
# 4     95
# 5     10
# 6      2
# 1      2
# Name: count, dtype: int64

# %%
# Visualisasi Distribusi Data ( Kamar Mandi )
hitung_kmandi = df['bathrooms'].value_counts().head(10)

plt.figure(figsize=(20, 10))
sns.barplot(x=hitung_kmandi.index, y=hitung_kmandi.values)
plt.title('bathrooms')
plt.xlabel('Present_Price')
plt.ylabel('Count')
plt.xticks()
plt.grid(axis='y')
plt.show()

# %%
print(hitung_kmandi)
# Out:
# bathrooms
# 1    401
# 2    133
# 3     10
# 4      1
# Name: count, dtype: int64

# %%
# Visualisasi ( Distribusi Top 10 Harga Tertinggi )
price = df['price'].value_counts().head(10)

plt.figure(figsize=(20, 10))
sns.barplot(x=price.index, y=price.values)
plt.title('Top 10 Selling_Price')
plt.xlabel('price')
plt.ylabel('Count')
plt.xticks()
plt.grid(axis='y')
plt.show()

# %%
print(price)
# Out:
# price
# 3500000    17
# 4200000    17
# 4900000    12
# 3150000     9
# 5600000     9
# 3640000     9
# 5250000     9
# 3360000     8
# 3290000     8
# 2940000     8
# Name: count, dtype: int64

# %%
# Cek missing values
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
# Cek Duplikasi
df.duplicated().sum()
# Out:
# 0

# %%
#  Cek Tipe Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# > # **Data Cleansing**

# %%
# Mengatasi Missing Value dengan metode "Fill Modus"
#df['Year'] = df['Year'].fillna(df['Year'].mode()[0])
#df['Publisher'] = df['Publisher'].fillna (df['Publisher'].mode()[0])

# %%
# Hapus nilai NaN (jika ada)
#df = df.dropna(axis=0)

# %%
#df.drop_duplicates(inplace=True)

# %%
# Tampilkan tabel
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# > # **Data Preprocessing**

# %%
# Import Library
#from sklearn.preprocessing import LabelEncoder

#le = LabelEncoder()

# %%
# Hapus Data yang tidak relevan
#df = df.drop(columns='Name', axis=1)

# %%
# Tampilkan tabel
df.head(5)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# Cek Kategorikal
df['furnishingstatus'].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
# Label Encoding
df['mainroad'] = df['mainroad'].map({'no': 0, 'yes': 1})

df['guestroom'] = df['guestroom'].map({'no': 0, 'yes': 1})

df['basement'] = df['basement'].map({'no': 0, 'yes': 1})

df['hotwaterheating'] = df['hotwaterheating'].map({'no': 0, 'yes': 1})

df['airconditioning'] = df['airconditioning'].map({'no': 0, 'yes': 1})

df['prefarea'] = df['prefarea'].map({'no': 0, 'yes': 1})

df['furnishingstatus'] = df['furnishingstatus'].map({'unfurnished': 0, 'semi-furnished': 1, 'furnished': 2})

# %%
# Encoding Label
#df['mainroad'] = le.fit_transform(df['mainroad'])
#df['guestroom'] = le.fit_transform(df['guestroom'])
#df['basement'] = le.fit_transform(df['basement'])
#df['hotwaterheating'] = le.fit_transform(df['hotwaterheating'])
#df['airconditioning'] = le.fit_transform(df['airconditioning'])
#df['prefarea'] = le.fit_transform(df['prefarea'])
#df['furnishingstatus'] = le.fit_transform(df['furnishingstatus'])

# %%
# Bedakan kolom fitur
#categorical_data = df[['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea', 'furnishingstatus']]
#numerical_data = df[['area', 'bedrooms', 'bathrooms', 'stories	', 'parking']]

# %%
#gabung = pd.concat([categorical_data, numerical_data], axis=1)

# %% [markdown]
# > # **Modelling**

# %%
# Import Library

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# %%
# Pisahkan variabel fitur dengan variabel target
X = df.drop(columns = 'price', axis=1)
Y = df['price']

# %%
# Standarisasi Min Max
#MMS = MinMaxScaler()
#X = MMS.fit_transform(X)
#Y = MMS.fit_transform(Y.values.reshape(-1, 1))

# %%
X
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
Y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
# Pisahkan data menjadi train dan test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Melatih Model Regression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Kecocokan Score Model
model.score(X_train, Y_train)
# Out:
# 0.6854429472843788

# %%
# Deteksi Overfitting
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

mse_train = mean_squared_error(Y_train, y_pred_train)
mse_test = mean_squared_error(Y_test, y_pred_test)

print("MSE Training:", mse_train)
print("MSE Testing:", mse_test)
# Out:
# MSE Training: 969902818698.3115
# MSE Testing: 1771751116594.0352

# %%
# Prediksi Test
Y_pred = model.predict(X_test)

# %% [markdown]
# > # **Evaluation**

# %%
# Evaluasi Model
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: ", mse)
print(f"R-squared: ", r2)
# Out:
# Mean Squared Error:  1771751116594.0352
# R-squared:  0.6494754192267803

# %%
# Scatter plot
plt.scatter(Y_test, Y_pred)
plt.xlabel('Sebenarnya')
plt.ylabel('Prediksi')
plt.show()

# %%
# Scatter plot
sns.scatterplot(x=Y_test, y=Y_pred)
plt.plot([Y_test.min(),Y_test.max()], [Y_test.min(),Y_test.max()], 'k-')
plt.xlabel('Actual Data')
plt.ylabel('Predicted Data')
plt.grid()
plt.show()
